# %% [markdown]
# # Assignment Data Visualization

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly as plt
import matplotlib.pyplot as plt

# %%
# Read the data
sns.set_theme()

# %%
# Load the example of the Titanic dataset
kashti = sns.load_dataset("titanic")
kashti.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.set_theme(style="whitegrid")

# %%
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=kashti, kind="bar",
    x="age", y="class", hue="sex",
    errorbar="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")

# %%
# Show the results of a linear regression within each dataset
sns.lmplot(
    data=kashti, x="age", y="fare", col="class", hue="pclass",
    col_wrap=2, palette="muted", ci=None,
    height=4, scatter_kws={"s": 50, "alpha": 1}
)

# %%
import seaborn as sns
sns.set_theme(style="ticks")

kashti = sns.load_dataset("titanic")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(
    data=kashti,
    x="pclass", y="age",
    hue="survived", size="sex", col="alive",
    kind="line", size_order=["T1", "T2"], palette=palette,
    height=5, aspect=.75, facet_kws=dict(sharex=False),
)
# Out:
# C:\Users\Anas Shafiq\AppData\Local\Temp\ipykernel_4572\1623340668.py:10: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.relplot(
